# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('American_Housing_Data_20231209.csv')
df.head()
# Out:
#    Zip Code      Price  Beds  Baths  Living Space                Address  \
# 0     10013  3999000.0     2      3          1967      74 GRAND ST APT 3
# 1     10013  3999000.0     2      3          1967      74 GRAND ST APT 3
# 2     10014  1650000.0     1      1           718  140 CHARLES ST APT 4D
# 3     10014   760000.0     3      2          1538            38 JONES ST
# 4     10014  1100000.0     1      1           600   81 BEDFORD ST APT 3F
#
#        City     State  Zip Code Population  Zip Code Density    County  \
# 0  New York  New York                29563           20967.9  New York
# 1  New York  New York                29563           20967.9  New York
# 2  New York  New York                29815           23740.9  New York
# 3  New York  New York                29815           23740.9  New York
# 4  New York  New York                29815           23740.9  New York
#
#    Median Household Income  Latitude  Longitude
# 0                 370046.0  40.72001  -74.00472
# ...

# %%
df.isnull().sum()
# Out:
# Zip Code                   0
# Price                      0
# Beds                       0
# Baths                      0
# Living Space               0
# Address                    0
# City                       0
# State                      0
# Zip Code Population        0
# Zip Code Density           0
# County                     0
# Median Household Income    2
# Latitude                   0
# Longitude                  0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.head()
# Out:
#    Zip Code      Price  Beds  Baths  Living Space                Address  \
# 0     10013  3999000.0     2      3          1967      74 GRAND ST APT 3
# 1     10013  3999000.0     2      3          1967      74 GRAND ST APT 3
# 2     10014  1650000.0     1      1           718  140 CHARLES ST APT 4D
# 3     10014   760000.0     3      2          1538            38 JONES ST
# 4     10014  1100000.0     1      1           600   81 BEDFORD ST APT 3F
#
#        City     State  Zip Code Population  Zip Code Density    County  \
# 0  New York  New York                29563           20967.9  New York
# 1  New York  New York                29563           20967.9  New York
# 2  New York  New York                29815           23740.9  New York
# 3  New York  New York                29815           23740.9  New York
# 4  New York  New York                29815           23740.9  New York
#
#    Median Household Income  Latitude  Longitude
# 0                 370046.0  40.72001  -74.00472
# ...

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df = df[df.Price<df.Price.quantile(0.99)]

# %%
sns.distplot(df.Price)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\824416946.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Price)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df.shape
# Out:
# (39578, 14)

# %%
df = df[df.Price<df.Price.quantile(0.99)]

# %%
df.shape
# Out:
# (39182, 14)

# %%
sns.distplot(df.Price)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\824416946.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Price)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df.head()
# Out:
#    Zip Code      Price  Beds  Baths  Living Space                Address  \
# 2     10014  1650000.0     1      1           718  140 CHARLES ST APT 4D
# 3     10014   760000.0     3      2          1538            38 JONES ST
# 4     10014  1100000.0     1      1           600   81 BEDFORD ST APT 3F
# 5     10017   764900.0     1      1           643  145 E 48TH ST APT 11E
# 6     10021  2499000.0     2      2          1471    234 E 70TH ST APT 4
#
#        City     State  Zip Code Population  Zip Code Density    County  \
# 2  New York  New York                29815           23740.9  New York
# 3  New York  New York                29815           23740.9  New York
# 4  New York  New York                29815           23740.9  New York
# 5  New York  New York                15514           20107.7  New York
# 6  New York  New York                42484           46004.0  New York
#
#    Median Household Income  Latitude  Longitude
# 2                 249880.0  40.73407  -74.00601
# ...

# %%
df.Address.value_counts()
# Out:
# Address
# 331 N 127TH ST E               20
# 1734 N STANTON PL              16
# 5535 ACKERFIELD AVE UNIT 26    16
# 1501 W 19TH ST                 16
# 1250 E OCEAN BLVD APT 407      12
#                                ..
# 5730 N 64TH ST                  1
# 5642 N 74TH ST                  1
# 4632 N 53RD ST                  1
# 4459 N 67TH ST                  1
# 2911 25TH AVE W                 1
# Name: count, Length: 38054, dtype: int64

# %%
len(df.Address.value_counts())
# Out:
# 38054

# %%
df[df['Zip Code Population']<0]
# Out:
# Empty DataFrame
# Columns: [Zip Code, Price, Beds, Baths, Living Space, Address, City, State, Zip Code Population, Zip Code Density, County, Median Household Income, Latitude, Longitude]
# Index: []

# %%
df.Beds.value_counts()
# Out:
# Beds
# 3     16710
# 4      9315
# 2      7797
# 5      2456
# 1      2138
# 6       506
# 7       120
# 8        79
# 12       17
# 9        12
# 10       12
# 11        8
# 14        3
# 24        2
# 13        1
# 16        1
# 22        1
# 17        1
# 28        1
# 25        1
# 54        1
# Name: count, dtype: int64

# %%
df[df.Beds>20]
# Out:
#        Zip Code      Price  Beds  Baths  Living Space  \
# 20        10301  2490000.0    24     10          7200
# 31355     89103   518000.0    22      2          1460
# 32264     90011  2250000.0    24     12         11434
# 34476     93702  1960000.0    28     14         11900
# 34477     93702  1755000.0    25     14          9650
# 35196     93728  1899998.0    54     56         33308
#
#                              Address           City       State  \
# 20            102 WINTER AVE APT 106  Staten Island    New York
# 31355  4575 DEAN MARTIN DR UNIT 1008      Las Vegas      Nevada
# 32264               716 E VERNON AVE    Los Angeles  California
# 34476              423 S DEARING AVE         Fresno  California
# 34477             424 S CHESTNUT AVE         Fresno  California
# 35196            1504 N VAN NESS AVE         Fresno  California
#
#        Zip Code Population  Zip Code Density       County  \
# 20                   38736            3980.1     Richmond
# ...

# %%
df.describe()
# Out:
#            Zip Code         Price          Beds         Baths  Living Space  \
# count  39182.000000  3.918200e+04  39182.000000  39182.000000  39182.000000
# mean   64665.037721  5.310168e+05      3.131412      2.398755   1834.064239
# std    25556.909216  4.342194e+05      1.151480      1.097385   1016.110453
# min    10014.000000  1.800000e+03      1.000000      1.000000      2.000000
# 25%    40215.000000  2.600000e+05      2.000000      2.000000   1200.000000
# 50%    74133.000000  3.985000e+05      3.000000      2.000000   1622.500000
# 75%    85711.000000  6.490000e+05      4.000000      3.000000   2217.000000
# max    98199.000000  2.790000e+06     54.000000     56.000000  74340.000000
#
#        Zip Code Population  Zip Code Density  Median Household Income  \
# count         39182.000000      39182.000000             39182.000000
# mean          37839.339824       2347.418404            109154.445409
# std           18733.492112       2904.054312             45106.361094
# ...

# %%
df = df[df['Beds']<df.Beds.quantile(0.99)]

# %%
df.Beds.value_counts()
# Out:
# Beds
# 3    16710
# 4     9315
# 2     7797
# 5     2456
# 1     2138
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (38416, 14)

# %%
sns.distplot(df.Beds)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\4215346182.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Beds)
# <Axes: xlabel='Beds', ylabel='Density'>

# %%
df.Baths.value_counts()
# Out:
# Baths
# 2     16702
# 3     10639
# 1      6859
# 4      3205
# 5       773
# 6       186
# 7        40
# 8         7
# 21        1
# 11        1
# 9         1
# 14        1
# 15        1
# Name: count, dtype: int64

# %%
df = df[df.Baths<8]

# %%
df.shape
# Out:
# (38404, 14)

# %%
df.head()
# Out:
#    Zip Code      Price  Beds  Baths  Living Space                Address  \
# 2     10014  1650000.0     1      1           718  140 CHARLES ST APT 4D
# 3     10014   760000.0     3      2          1538            38 JONES ST
# 4     10014  1100000.0     1      1           600   81 BEDFORD ST APT 3F
# 5     10017   764900.0     1      1           643  145 E 48TH ST APT 11E
# 6     10021  2499000.0     2      2          1471    234 E 70TH ST APT 4
#
#        City     State  Zip Code Population  Zip Code Density    County  \
# 2  New York  New York                29815           23740.9  New York
# 3  New York  New York                29815           23740.9  New York
# 4  New York  New York                29815           23740.9  New York
# 5  New York  New York                15514           20107.7  New York
# 6  New York  New York                42484           46004.0  New York
#
#    Median Household Income  Latitude  Longitude
# 2                 249880.0  40.73407  -74.00601
# ...

# %%
df.drop(['Address','City','State','County'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Zip Code      Price  Beds  Baths  Living Space  Zip Code Population  \
# 2     10014  1650000.0     1      1           718                29815
# 3     10014   760000.0     3      2          1538                29815
# 4     10014  1100000.0     1      1           600                29815
# 5     10017   764900.0     1      1           643                15514
# 6     10021  2499000.0     2      2          1471                42484
#
#    Zip Code Density  Median Household Income  Latitude  Longitude
# 2           23740.9                 249880.0  40.73407  -74.00601
# 3           23740.9                 249880.0  40.73407  -74.00601
# 4           23740.9                 249880.0  40.73407  -74.00601
# 5           20107.7                 188289.0  40.75235  -73.97260
# 6           46004.0                 261254.0  40.76963  -73.95899

# %%
df['Zip Code'].value_counts()
# Out:
# Zip Code
# 79928    192
# 93727    185
# 23456    178
# 27610    156
# 85212    146
#         ...
# 27703      1
# 28078      1
# 11238      1
# 28104      1
# 93230      1
# Name: count, Length: 1715, dtype: int64

# %%
sns.distplot(df['Zip Code'])
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\434028403.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Zip Code'])
# <Axes: xlabel='Zip Code', ylabel='Density'>

# %%
sns.distplot(df.Baths)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\1203369016.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Baths)
# <Axes: xlabel='Baths', ylabel='Density'>

# %%
df.head()
# Out:
#    Zip Code      Price  Beds  Baths  Living Space  Zip Code Population  \
# 2     10014  1650000.0     1      1           718                29815
# 3     10014   760000.0     3      2          1538                29815
# 4     10014  1100000.0     1      1           600                29815
# 5     10017   764900.0     1      1           643                15514
# 6     10021  2499000.0     2      2          1471                42484
#
#    Zip Code Density  Median Household Income  Latitude  Longitude
# 2           23740.9                 249880.0  40.73407  -74.00601
# 3           23740.9                 249880.0  40.73407  -74.00601
# 4           23740.9                 249880.0  40.73407  -74.00601
# 5           20107.7                 188289.0  40.75235  -73.97260
# 6           46004.0                 261254.0  40.76963  -73.95899

# %%
df = df[df['Zip Code']<df['Zip Code'].quantile(0.99)]

# %%
df.shape
# Out:
# (38003, 10)

# %%
sns.distplot(df['Zip Code'])
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\434028403.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Zip Code'])
# <Axes: xlabel='Zip Code', ylabel='Density'>

# %%
df.head()
# Out:
#    Zip Code      Price  Beds  Baths  Living Space  Zip Code Population  \
# 2     10014  1650000.0     1      1           718                29815
# 3     10014   760000.0     3      2          1538                29815
# 4     10014  1100000.0     1      1           600                29815
# 5     10017   764900.0     1      1           643                15514
# 6     10021  2499000.0     2      2          1471                42484
#
#    Zip Code Density  Median Household Income  Latitude  Longitude
# 2           23740.9                 249880.0  40.73407  -74.00601
# 3           23740.9                 249880.0  40.73407  -74.00601
# 4           23740.9                 249880.0  40.73407  -74.00601
# 5           20107.7                 188289.0  40.75235  -73.97260
# 6           46004.0                 261254.0  40.76963  -73.95899

# %%
plt.plot(df['Living Space'],df.Price)

# %%
sns.distplot(df['Living Space'])
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\259990242.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Living Space'])
# <Axes: xlabel='Living Space', ylabel='Density'>

# %%
df.describe()
# Out:
#            Zip Code         Price          Beds         Baths  Living Space  \
# count  38003.000000  3.800300e+04  38003.000000  38003.000000  38003.000000
# mean   64356.838697  5.163162e+05      3.059258      2.351683   1795.304423
# std    25396.908927  4.197149e+05      0.957501      0.976256    948.843404
# min    10014.000000  1.800000e+03      1.000000      1.000000      2.000000
# 25%    40212.000000  2.598000e+05      2.000000      2.000000   1198.000000
# 50%    74127.000000  3.890000e+05      3.000000      2.000000   1607.000000
# 75%    85254.000000  6.249000e+05      4.000000      3.000000   2182.000000
# max    98117.000000  2.790000e+06      5.000000      7.000000  74340.000000
#
#        Zip Code Population  Zip Code Density  Median Household Income  \
# count         38003.000000      38003.000000             38003.000000
# mean          37877.160435       2293.467018            108640.531484
# std           18766.298497       2806.907504             44952.356258
# ...

# %%
df = df[df['Living Space']<df['Living Space'].quantile(0.99)]

# %%
df.shape
# Out:
# (37622, 10)

# %%
df = df[df['Living Space']>df['Living Space'].quantile(0.01)]

# %%
df.shape
# Out:
# (37243, 10)

# %%
df.describe()
# Out:
#            Zip Code         Price          Beds         Baths  Living Space  \
# count  37243.000000  3.724300e+04  37243.000000  37243.000000  37243.000000
# mean   64438.664581  5.086560e+05      3.062267      2.337083   1768.105792
# std    25380.273358  4.042462e+05      0.936502      0.931149    769.149132
# min    10014.000000  1.800000e+03      1.000000      1.000000    561.000000
# 25%    40215.000000  2.599000e+05      2.000000      2.000000   1200.000000
# 50%    74129.000000  3.890000e+05      3.000000      2.000000   1607.000000
# 75%    85306.000000  6.149000e+05      4.000000      3.000000   2166.000000
# max    98117.000000  2.790000e+06      5.000000      7.000000   4749.000000
#
#        Zip Code Population  Zip Code Density  Median Household Income  \
# count         37243.000000      37243.000000             37243.000000
# mean          37976.800231       2285.198792            108440.175765
# std           18790.449476       2794.621626             44800.971751
# ...

# %%
df.head()
# Out:
#    Zip Code      Price  Beds  Baths  Living Space  Zip Code Population  \
# 2     10014  1650000.0     1      1           718                29815
# 3     10014   760000.0     3      2          1538                29815
# 4     10014  1100000.0     1      1           600                29815
# 5     10017   764900.0     1      1           643                15514
# 6     10021  2499000.0     2      2          1471                42484
#
#    Zip Code Density  Median Household Income  Latitude  Longitude
# 2           23740.9                 249880.0  40.73407  -74.00601
# 3           23740.9                 249880.0  40.73407  -74.00601
# 4           23740.9                 249880.0  40.73407  -74.00601
# 5           20107.7                 188289.0  40.75235  -73.97260
# 6           46004.0                 261254.0  40.76963  -73.95899

# %%
sns.distplot(df['Zip Code Population'])
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\1112285986.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Zip Code Population'])
# <Axes: xlabel='Zip Code Population', ylabel='Density'>

# %%
df = df[df['Zip Code Population']<df['Zip Code Population'].quantile(0.99)]

# %%
df.shape
# Out:
# (36818, 10)

# %%
sns.distplot(df['Zip Code Population'])
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\1112285986.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Zip Code Population'])
# <Axes: xlabel='Zip Code Population', ylabel='Density'>

# %%
df.head()
# Out:
#    Zip Code      Price  Beds  Baths  Living Space  Zip Code Population  \
# 2     10014  1650000.0     1      1           718                29815
# 3     10014   760000.0     3      2          1538                29815
# 4     10014  1100000.0     1      1           600                29815
# 5     10017   764900.0     1      1           643                15514
# 6     10021  2499000.0     2      2          1471                42484
#
#    Zip Code Density  Median Household Income  Latitude  Longitude
# 2           23740.9                 249880.0  40.73407  -74.00601
# 3           23740.9                 249880.0  40.73407  -74.00601
# 4           23740.9                 249880.0  40.73407  -74.00601
# 5           20107.7                 188289.0  40.75235  -73.97260
# 6           46004.0                 261254.0  40.76963  -73.95899

# %%
df.describe()
# Out:
#            Zip Code         Price          Beds         Baths  Living Space  \
# count  36818.000000  3.681800e+04  36818.000000  36818.000000  36818.000000
# mean   64390.378891  5.093211e+05      3.060106      2.337607   1769.707453
# std    25339.254703  4.054569e+05      0.937577      0.932720    770.749873
# min    10014.000000  1.800000e+03      1.000000      1.000000    561.000000
# 25%    40214.000000  2.599000e+05      2.000000      2.000000   1200.000000
# 50%    74115.000000  3.890000e+05      3.000000      2.000000   1608.000000
# 75%    85308.000000  6.140000e+05      4.000000      3.000000   2168.750000
# max    98117.000000  2.790000e+06      5.000000      7.000000   4749.000000
#
#        Zip Code Population  Zip Code Density  Median Household Income  \
# count         36818.000000      36818.000000             36818.000000
# mean          37291.997447       2267.325705            108643.754332
# std           17764.620977       2744.205000             44976.793502
# ...

# %%
sns.distplot(df['Zip Code Density'])
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\298093637.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Zip Code Density'])
# <Axes: xlabel='Zip Code Density', ylabel='Density'>

# %%
df = df[df['Zip Code Density']<df['Zip Code Density'].quantile(0.99)]

# %%
df.shape
# Out:
# (36383, 10)

# %%
sns.distplot(df['Zip Code Density'])
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\298093637.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Zip Code Density'])
# <Axes: xlabel='Zip Code Density', ylabel='Density'>

# %%
df.head()
# Out:
#     Zip Code      Price  Beds  Baths  Living Space  Zip Code Population  \
# 19     10301   750000.0     4      2          1853                38736
# 21     10301  1148888.0     4      3          1980                38736
# 22     10301   998000.0     3      1          2288                38736
# 23     10301   849000.0     4      2          2511                38736
# 24     10301   575000.0     2      1          1200                38736
#
#     Zip Code Density  Median Household Income  Latitude  Longitude
# 19            3980.1                 118113.0  40.62803  -74.09564
# 21            3980.1                 118113.0  40.62803  -74.09564
# 22            3980.1                 118113.0  40.62803  -74.09564
# 23            3980.1                 118113.0  40.62803  -74.09564
# 24            3980.1                 118113.0  40.62803  -74.09564

# %%
df.describe()
# Out:
#            Zip Code         Price          Beds         Baths  Living Space  \
# count  36383.000000  3.638300e+04  36383.000000  36383.000000  36383.000000
# mean   64622.415139  5.044515e+05      3.073331      2.342330   1776.024517
# std    25162.962161  4.008743e+05      0.929934      0.932074    770.151371
# min    10301.000000  1.800000e+03      1.000000      1.000000    561.000000
# 25%    40219.000000  2.595000e+05      3.000000      2.000000   1202.000000
# 50%    74129.000000  3.850000e+05      3.000000      2.000000   1614.000000
# 75%    85308.000000  6.000000e+05      4.000000      3.000000   2175.000000
# max    98117.000000  2.790000e+06      5.000000      7.000000   4749.000000
#
#        Zip Code Population  Zip Code Density  Median Household Income  \
# count         36383.000000      36383.000000             36383.000000
# mean          37242.277712       2071.349111            108006.724212
# std           17735.352997       1983.634966             44635.176783
# ...

# %%
sns.distplot(df['Median Household Income'])
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\321756320.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Median Household Income'])
# <Axes: xlabel='Median Household Income', ylabel='Density'>

# %%
df = df[df['Median Household Income']<df['Median Household Income'].quantile(0.99)]

# %%
df.describe()
# Out:
#            Zip Code         Price          Beds         Baths  Living Space  \
# count  36013.000000  3.601300e+04  36013.000000  36013.000000   36013.00000
# mean   64490.773554  4.962256e+05      3.077639      2.340960    1775.39258
# std    25108.089567  3.893093e+05      0.927281      0.929575     768.57393
# min    10301.000000  1.800000e+03      1.000000      1.000000     561.00000
# 25%    40218.000000  2.575000e+05      3.000000      2.000000    1203.00000
# 50%    74114.000000  3.824990e+05      3.000000      2.000000    1614.00000
# 75%    85213.000000  5.990000e+05      4.000000      3.000000    2172.00000
# max    98117.000000  2.790000e+06      5.000000      7.000000    4749.00000
#
#        Zip Code Population  Zip Code Density  Median Household Income  \
# count         36013.000000      36013.000000             36013.000000
# mean          37361.904507       2054.756449            106122.960153
# std           17753.082071       1955.584464             40605.011565
# ...

# %%
df.shape
# Out:
# (36013, 10)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df.columns
# Out:
# Index(['Zip Code', 'Price', 'Beds', 'Baths', 'Living Space',
#        'Zip Code Population', 'Zip Code Density', 'Median Household Income',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.head()
# Out:
#     Zip Code      Price  Beds  Baths  Living Space  Zip Code Population  \
# 19     10301   750000.0     4      2          1853                38736
# 21     10301  1148888.0     4      3          1980                38736
# 22     10301   998000.0     3      1          2288                38736
# 23     10301   849000.0     4      2          2511                38736
# 24     10301   575000.0     2      1          1200                38736
#
#     Zip Code Density  Median Household Income  Latitude  Longitude
# 19            3980.1                 118113.0  40.62803  -74.09564
# 21            3980.1                 118113.0  40.62803  -74.09564
# 22            3980.1                 118113.0  40.62803  -74.09564
# 23            3980.1                 118113.0  40.62803  -74.09564
# 24            3980.1                 118113.0  40.62803  -74.09564

# %%
df1 = df.copy()
columns = ['Zip Code', 'Beds', 'Baths', 'Living Space',
       'Zip Code Population', 'Zip Code Density', 'Median Household Income',
       'Latitude', 'Longitude']

# %%
df.describe()
# Out:
#            Zip Code         Price          Beds         Baths  Living Space  \
# count  36013.000000  3.601300e+04  36013.000000  36013.000000   36013.00000
# mean   64490.773554  4.962256e+05      3.077639      2.340960    1775.39258
# std    25108.089567  3.893093e+05      0.927281      0.929575     768.57393
# min    10301.000000  1.800000e+03      1.000000      1.000000     561.00000
# 25%    40218.000000  2.575000e+05      3.000000      2.000000    1203.00000
# 50%    74114.000000  3.824990e+05      3.000000      2.000000    1614.00000
# 75%    85213.000000  5.990000e+05      4.000000      3.000000    2172.00000
# max    98117.000000  2.790000e+06      5.000000      7.000000    4749.00000
#
#        Zip Code Population  Zip Code Density  Median Household Income  \
# count         36013.000000      36013.000000             36013.000000
# mean          37361.904507       2054.756449            106122.960153
# std           17753.082071       1955.584464             40605.011565
# ...

# %%
len(df[df['Zip Code']>df['Zip Code'].quantile(0.75)])
# Out:
# 8984

# %%
df[df['Living Space']>df['Living Space'].quantile(0.99)]
# Out:
#        Zip Code      Price  Beds  Baths  Living Space  Zip Code Population  \
# 59        10304  1189000.0     3      4          4629                43849
# 121       10310  1750000.0     4      4          4500                25976
# 1379      20001  2689000.0     5      5          4205                45551
# 1676      20008  2700000.0     5      6          4600                30461
# 2320      21209   949900.0     4      5          4616                30146
# ...         ...        ...   ...    ...           ...                  ...
# 38877     97225  1295000.0     3      3          4238                26202
# 38917     97229  1145000.0     5      3          4243                72974
# 38942     97229  1189000.0     3      4          4280                72974
# 38969     97230   779000.0     5      5          4570                41563
# 39014     97232   949900.0     5      2          4354                14780
#
# ...

# %%
df = df[~(df['Living Space']/df['Beds']<300)]

# %%
df.shape
# Out:
# (35492, 10)

# %%
df['Price_per_sqft'] = df['Price']/df['Living Space']

# %%
df.head()
# Out:
#     Zip Code      Price  Beds  Baths  Living Space  Zip Code Population  \
# 19     10301   750000.0     4      2          1853                38736
# 21     10301  1148888.0     4      3          1980                38736
# 22     10301   998000.0     3      1          2288                38736
# 23     10301   849000.0     4      2          2511                38736
# 24     10301   575000.0     2      1          1200                38736
#
#     Zip Code Density  Median Household Income  Latitude  Longitude  \
# 19            3980.1                 118113.0  40.62803  -74.09564
# 21            3980.1                 118113.0  40.62803  -74.09564
# 22            3980.1                 118113.0  40.62803  -74.09564
# 23            3980.1                 118113.0  40.62803  -74.09564
# 24            3980.1                 118113.0  40.62803  -74.09564
#
#     Price_per_sqft
# 19      404.749056
# 21      580.246465
# 22      436.188811
# 23      338.112306
# 24      479.166667

# %%
df.describe()
# Out:
#            Zip Code         Price          Beds         Baths  Living Space  \
# count  35492.000000  3.549200e+04  35492.000000  35492.000000  35492.000000
# mean   64572.199792  4.995028e+05      3.069565      2.351854   1787.071255
# std    25127.225219  3.900864e+05      0.927073      0.927936    767.704736
# min    10301.000000  1.800000e+03      1.000000      1.000000    561.000000
# 25%    40218.000000  2.599900e+05      3.000000      2.000000   1221.000000
# 50%    74128.000000  3.850000e+05      3.000000      2.000000   1627.000000
# 75%    85215.000000  5.991152e+05      4.000000      3.000000   2184.000000
# max    98117.000000  2.790000e+06      5.000000      7.000000   4749.000000
#
#        Zip Code Population  Zip Code Density  Median Household Income  \
# count         35492.000000      35492.000000             35492.000000
# mean          37342.665671       2049.918227            106579.579483
# std           17771.322952       1959.295213             40580.931535
# ...

# %%
sns.distplot(df.Price_per_sqft)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\1858562761.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Price_per_sqft)
# <Axes: xlabel='Price_per_sqft', ylabel='Density'>

# %%
df = df[df['Price_per_sqft']>df['Price_per_sqft'].quantile(0.01)]

# %%
sns.distplot(df.Price_per_sqft)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_560\1858562761.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Price_per_sqft)
# <Axes: xlabel='Price_per_sqft', ylabel='Density'>

# %%
df.describe()
# Out:
#            Zip Code         Price          Beds         Baths  Living Space  \
# count  35137.000000  3.513700e+04  35137.000000  35137.000000  35137.000000
# mean   64729.031448  5.040707e+05      3.070865      2.360759   1790.851695
# std    25142.172073  3.893726e+05      0.927678      0.926011    768.431916
# min    10301.000000  3.500000e+04      1.000000      1.000000    561.000000
# 25%    40218.000000  2.649500e+05      3.000000      2.000000   1224.000000
# 50%    74133.000000  3.890000e+05      3.000000      2.000000   1630.000000
# 75%    85306.000000  5.999870e+05      4.000000      3.000000   2190.000000
# max    98117.000000  2.790000e+06      5.000000      7.000000   4749.000000
#
#        Zip Code Population  Zip Code Density  Median Household Income  \
# count         35137.000000      35137.000000             35137.000000
# mean          37396.996869       2047.890392            107038.142386
# std           17796.538582       1962.030639             40450.340131
# ...

# %%
df.shape
# Out:
# (35137, 11)

# %%
df.head()
# Out:
#     Zip Code      Price  Beds  Baths  Living Space  Zip Code Population  \
# 19     10301   750000.0     4      2          1853                38736
# 21     10301  1148888.0     4      3          1980                38736
# 22     10301   998000.0     3      1          2288                38736
# 23     10301   849000.0     4      2          2511                38736
# 24     10301   575000.0     2      1          1200                38736
#
#     Zip Code Density  Median Household Income  Latitude  Longitude  \
# 19            3980.1                 118113.0  40.62803  -74.09564
# 21            3980.1                 118113.0  40.62803  -74.09564
# 22            3980.1                 118113.0  40.62803  -74.09564
# 23            3980.1                 118113.0  40.62803  -74.09564
# 24            3980.1                 118113.0  40.62803  -74.09564
#
#     Price_per_sqft
# 19      404.749056
# 21      580.246465
# 22      436.188811
# 23      338.112306
# 24      479.166667

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df.columns
# Out:
# Index(['Zip Code', 'Price', 'Beds', 'Baths', 'Living Space',
#        'Zip Code Population', 'Zip Code Density', 'Median Household Income',
#        'Latitude', 'Longitude', 'Price_per_sqft'],
#       dtype='object')

# %%
columns = ['Zip Code', 'Beds', 'Baths', 'Living Space',
       'Zip Code Population', 'Zip Code Density', 'Median Household Income',
       'Latitude', 'Longitude', 'Price_per_sqft']

# %%
df[columns] = scaler.fit_transform(df[columns])

# %%
df.head()
# Out:
#     Zip Code      Price  Beds     Baths  Living Space  Zip Code Population  \
# 19       0.0   750000.0  0.75  0.166667      0.308500              0.42563
# 21       0.0  1148888.0  0.75  0.333333      0.338825              0.42563
# 22       0.0   998000.0  0.50  0.000000      0.412369              0.42563
# 23       0.0   849000.0  0.75  0.166667      0.465616              0.42563
# 24       0.0   575000.0  0.25  0.000000      0.152579              0.42563
#
#     Zip Code Density  Median Household Income  Latitude  Longitude  \
# 19          0.270253                 0.416761  0.678475   0.992038
# 21          0.270253                 0.416761  0.678475   0.992038
# 22          0.270253                 0.416761  0.678475   0.992038
# 23          0.270253                 0.416761  0.678475   0.992038
# 24          0.270253                 0.416761  0.678475   0.992038
#
#     Price_per_sqft
# 19        0.099561
# 21        0.148797
# 22        0.108381
# 23        0.080866
# ...

# %%
df['Zip Code'].describe()
# Out:
# count    35137.000000
# mean         0.619796
# std          0.286305
# min          0.000000
# 25%          0.340678
# 50%          0.726883
# 75%          0.854115
# max          1.000000
# Name: Zip Code, dtype: float64

# %%
X = df.drop('Price',axis=1)
y = df.Price

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.8638765131953562

# %%
import pickle
with open('model.pickle','wb') as f:
    pickle.dump(model,f)

# %%
df.columns
# Out:
# Index(['Zip Code', 'Price', 'Beds', 'Baths', 'Living Space',
#        'Zip Code Population', 'Zip Code Density', 'Median Household Income',
#        'Latitude', 'Longitude', 'Price_per_sqft'],
#       dtype='object')
